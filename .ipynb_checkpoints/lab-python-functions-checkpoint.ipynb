# %% [markdown]
# # Lab | Functions

# %% [markdown]
# ## Exercise: Managing Customer Orders with Functions
#
# In the previous exercise, you improved the code for managing customer orders by using loops and flow control. Now, let's take it a step further and refactor the code by introducing functions.
#
# Follow the steps below to complete the exercise:
#
# 1. Define a function named `initialize_inventory` that takes `products` as a parameter. Inside the function, implement the code for initializing the inventory dictionary using a loop and user input.
#
# 2. Define a function named `get_customer_orders` that takes no parameters. Inside the function, implement the code for prompting the user to enter the product names using a loop. The function should return the `customer_orders` set.
#
# 3. Define a function named `update_inventory` that takes `customer_orders` and `inventory` as parameters. Inside the function, implement the code for updating the inventory dictionary based on the customer orders.
#
# 4. Define a function named `calculate_order_statistics` that takes `customer_orders` and `products` as parameters. Inside the function, implement the code for calculating the order statistics (total products ordered, and percentage of unique products ordered). The function should return these values.
#
# 5. Define a function named `print_order_statistics` that takes `order_statistics` as a parameter. Inside the function, implement the code for printing the order statistics.
#
# 6. Define a function named `print_updated_inventory` that takes `inventory` as a parameter. Inside the function, implement the code for printing the updated inventory.
#
# 7. Call the functions in the appropriate sequence to execute the program and manage customer orders.
#
# Hints for functions:
#
# - Consider the input parameters required for each function and their return values.
# - Utilize function parameters and return values to transfer data between functions.
# - Test your functions individually to ensure they work correctly.

# %%
##Define a function named initialize_inventory that takes products as a parameter. Inside the function, implement 
##the code for initializing the inventory dictionary using a loop and user input.

products=['t-shirt', 'mug', 'hat', 'book', 'keychain']
inventory={}

def initialize_inventory(products_list):
    for item in products:
        inventory[item]=int(input(f'Enter the quantity of the product {item} '))
    
##Define a function named get_customer_orders that takes no parameters. Inside the function, implement the code 
##for prompting the user to enter the product names using a loop. The function should return the customer_orders set.

def get_customer_orders():
    "Input done by user"
    customer_orders={'t-shirt': 0, 'mug': 0, 'hat': 0, 'book': 0, 'keychain': 0}
    order='yes'
    while order=='yes':
        user_input=input('Enter the numero of the product you want to order: 1.t-shirt 2.mug 3.hat 4.book 5.keychain ')
        if user_input=='1':
            customer_orders['t-shirt']+=int(input('Quantity:'))            
            order=input('Do you want to order another item? Enter yes or no ')
        elif user_input=='2':
            customer_orders['mug']+=int(input('Quantity:'))
            order=input('Do you want to order another item? Enter yes or no ')
        elif user_input=='3':
            customer_orders['hat']+=int(input('Quantity:'))
            order=input('Do you want to order another item? Enter yes or no ')
        elif user_input=='4':
            customer_orders['book']+=int(input('Quantity:'))
            order=input('Do you want to order another item? Enter yes or no ')
        elif user_input=='5':
            customer_orders['keychain']+=int(input('Quantity:'))
            order=input('Do you want to order another item? Enter yes or no ')
    return customer_orders

##Define a function named update_inventory that takes customer_orders and inventory as parameters. Inside the 
##function, implement the code for updating the inventory dictionary based on the customer orders.

def update_inventory(inventory , customer_orders):
    "This is for updating the inventory with the customer orders"
    for product in inventory:
        inventory[product]=(inventory.get(product)-customer_orders[product])
    return inventory

##Define a function named calculate_order_statistics that takes customer_orders and products as parameters. 
##Inside the function, implement the code for calculating the order statistics (total products ordered, and 
##percentage of unique products ordered). The function should return these values.                            

def calculate_order_statistics(customer_orders, inventory):
    percentage={}
    total_products_ordered=0
    for orders in customer_orders.values():
        total_products_ordered=sum(customer_orders.values()) 
        #print(total_products_ordered)    
    for orders in customer_orders:
        try:
            percentage[orders]=float((customer_orders.get(orders)/inventory.get(orders))*100)
        except ZeroDivisionError:
            percentage[orders]='inventory empty'
    return f'Total products ordered {total_products_ordered}',f'Percentage of each product on the inventory {percentage}'

##Define a function named print_order_statistics that takes order_statistics as a parameter. Inside the function, 
##implement the code for printing the order statistics.
    
def print_order_statistics(calculate_order_statistics):
    """"result of calculate_order_statistics"""
    return calculate_order_statistics

##Define a function named print_updated_inventory that takes inventory as a parameter. Inside the function, 
##implement the code for printing the updated inventory.                           

def print_updated_inventory(update_inventory):
    """"result of update_inventory"""
    return update_inventory

# %%
##Call the functions in the appropriate sequence to execute the program and manage customer orders.

a=initialize_inventory(products)
print('\n')
print(f'Initial inventory {inventory}')
print('\n')
b=get_customer_orders()
print('\n')
print(f'Customer order: {b}')
print('\n')
c=calculate_order_statistics(b,inventory)
d=print_order_statistics(c)
print('\n')
print(f':Statistics from the order over the inventory: {d}')
print('\n')
e=update_inventory(inventory,b)
f=print_updated_inventory(e)
print('\n')
print(f':Final inventory: {f}')
print('\n')
# Out:
# Enter the quantity of the product t-shirt 50
# Enter the quantity of the product mug 35
# Enter the quantity of the product hat 0
# Enter the quantity of the product book 65
# Enter the quantity of the product keychain 122
#
#
# Initial inventory {'t-shirt': 50, 'mug': 35, 'hat': 0, 'book': 65, 'keychain': 122}
#
#
# Enter the numero of the product you want to order: 1.t-shirt 2.mug 3.hat 4.book 5.keychain 1
# Quantity:50
# Do you want to order another item? Enter yes or no yes
# Enter the numero of the product you want to order: 1.t-shirt 2.mug 3.hat 4.book 5.keychain 2
# Quantity:2
# Do you want to order another item? Enter yes or no yes
# Enter the numero of the product you want to order: 1.t-shirt 2.mug 3.hat 4.book 5.keychain 3
# Quantity:1
# Do you want to order another item? Enter yes or no yes
# Enter the numero of the product you want to order: 1.t-shirt 2.mug 3.hat 4.book 5.keychain 5
# Quantity:103
# Do you want to order another item? Enter yes or no no
#
#
# ...
